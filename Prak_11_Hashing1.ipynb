# %% [markdown]
# # Image Hashing
# Image Hashing adalah teknik yang digunakan untuk mengkonversi gambar ke string alfanumerik. Image Hashing memiliki dua kegunaan utama: memungkinkan mendeteksi gambar yang identik atau serupa secara visual, dan memungkinkan menyimpan sidik jari gambar sehingga Anda tidak perlu memuat ulang setiap gambar untuk memeriksanya. <br>
#
# # Cara Kerja Image Hashing
# Hashing mengubah gambar menjadi string alfanumerik pendek yang mewakili keunikan gambar. Karena hash adalah string kecil dan berbasis teks, seperti <b>e7643c330f0f0f0f</b>, hash dapat disimpan tanpa menghabiskan banyak ruang dan dapat dicari serta dibandingkan dengan cepat.

# %% [markdown]
# ### Pindah ke directory file imagehash

# %%
cd D:/imagehash/
# Out:
# D:\imagehash

# %% [markdown]
# ### Install library

# %%
# !pip install -r conda-requirements.txt
# Out:
# Requirement already satisfied: six in c:\users\hangg\anaconda3\lib\site-packages (from -r conda-requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pillow in c:\users\hangg\anaconda3\lib\site-packages (from -r conda-requirements.txt (line 2)) (8.2.0)
# Requirement already satisfied: numpy in c:\users\hangg\anaconda3\lib\site-packages (from -r conda-requirements.txt (line 3)) (1.19.5)
# Requirement already satisfied: scipy in c:\users\hangg\anaconda3\lib\site-packages (from -r conda-requirements.txt (line 4)) (1.6.2)
# Requirement already satisfied: pywavelets in c:\users\hangg\anaconda3\lib\site-packages (from -r conda-requirements.txt (line 5)) (1.1.1)

# %% [markdown]
# ## Average Hash Image

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.average_hash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.average_hash(Image.open('Whalee.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: fffff9efff0f0000
# Hash Gambar 2: ffff9ff7fff00000
# Gambar berbeda, perbedaan hash: 14

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.average_hash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.average_hash(Image.open('Whale.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: fffff9efff0f0000
# Hash Gambar 2: fffff9efff0f0000
# Gambar mirip!

# %% [markdown]
# ## Perception Hashing

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.phash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.phash(Image.open('Whalee.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: 81cf6e90d1370dce
# Hash Gambar 2: d49a3bc5a462d89b
# Gambar berbeda, perbedaan hash: 34

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.phash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.phash(Image.open('Whale.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: 81cf6e90d1370dce
# Hash Gambar 2: 81cf6e90d1370dce
# Gambar mirip!

# %% [markdown]
# ## Difference Hashing

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.dhash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.dhash(Image.open('Whalee.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: e0f1631ef0fc1fc0
# Hash Gambar 2: f0703987f0c007f4
# Gambar berbeda, perbedaan hash: 20

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.dhash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.dhash(Image.open('Whale.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: e0f1631ef0fc1fc0
# Hash Gambar 2: e0f1631ef0fc1fc0
# Gambar mirip!

# %% [markdown]
# ## Wavelet Hashing

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.whash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.whash(Image.open('Whalee.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: 10fef1efff0f0000
# Hash Gambar 2: 087f8ff7fff00000
# Gambar berbeda, perbedaan hash: 20

# %%
#Import Library
from PIL import Image
import imagehash

#Membuat Objek hash gambar 1
HashGambar1 = imagehash.whash(Image.open('Whale.jpg'))
print('Hash Gambar 1: ' + str(HashGambar1))

#Membuat Objek hash gambar 2
HashGambar2 = imagehash.whash(Image.open('Whale.jpg'))
print('Hash Gambar 2: ' + str(HashGambar2))

#Membandingkan Objek Hash
if(HashGambar1 == HashGambar2):
    print("Gambar mirip!")
else:
    print("Gambar berbeda, perbedaan hash: " + str(HashGambar1 - HashGambar2))
# Out:
# Hash Gambar 1: 10fef1efff0f0000
# Hash Gambar 2: 10fef1efff0f0000
# Gambar mirip!
